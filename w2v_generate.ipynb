# %%
import scipy.io as sio
import pandas as pd
import numpy as np

# %%
description = pd.read_excel('CUB_description.xlsx')

description.head()
# Out:
#                 Bird_name                                  Short_Description
# 0  Black footed Albatross  The Black-footed Albatross is a large seabird ...
# 1        Laysan Albatross  The Laysan Albatross is a large seabird with a...
# 2         Sooty Albatross  The Sooty Albatross is a large seabird known f...
# 3       Groove billed Ani  The Groove-billed Ani bird is a medium-sized b...
# 4          Crested Auklet  The Crested Auklet is a small seabird with a d...

# %%
import gensim
from gensim.models.doc2vec import Word2Vec
import gensim.downloader as api
import nltk
# nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(list(api.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
wv = api.load('word2vec-google-news-300')

# %%
def preprocess_text(text):
    text = text.lower()

    words = gensim.utils.simple_preprocess(text)

    stop_words = gensim.parsing.preprocessing.STOPWORDS
    words = [word for word in words if word not in stop_words]

    return words

# %%
def get_sentence_embedding(sentence):
    words = preprocess_text(sentence)

    word_embeddings = [wv[word] for word in words if word in wv]

    sentence_embedding = np.mean(word_embeddings, axis=0)

    return sentence_embedding

# %%
def get_paragraph_embedding(paragraph):
    sentences = nltk.sent_tokenize(paragraph)

    sentence_embeddings = [get_sentence_embedding(sentence) for sentence in sentences]

    paragraph_embedding = np.mean(sentence_embeddings, axis=0)

    return paragraph_embedding

# %%
paragraph = "This is a sample paragraph. It contains multiple sentences."
paragraph_embedding = get_paragraph_embedding(paragraph)

# %%
paragraph_embedding.shape
# Out:
# (300,)

# %%
paragraph_embedding
# Out:
# array([-0.03771464, -0.0402832 ,  0.19514975, -0.04826355, -0.02701823,
#        -0.05029297,  0.083903  ,  0.04135132,  0.05739339,  0.13986206,
#        -0.11649577, -0.05000814,  0.01379395,  0.15749106, -0.07039388,
#         0.10304768, -0.0608724 ,  0.12445068, -0.15877278, -0.16764322,
#        -0.02596029, -0.00866699, -0.22224934,  0.02697754, -0.02156575,
#        -0.09277344, -0.05086263,  0.08154297,  0.02331543,  0.15952554,
#        -0.08418783, -0.10685221, -0.04372152,  0.06189982,  0.00406901,
#         0.17419434,  0.01103719, -0.01224772, -0.08784994,  0.08756511,
#         0.08237712,  0.09376526,  0.01020304,  0.13675945,  0.00199382,
#        -0.13242593, -0.03637695,  0.04398092, -0.21626791, -0.06312244,
#        -0.07623291, -0.20450847, -0.10894775, -0.0921224 ,  0.01692708,
#        -0.03045654,  0.06778971, -0.08264669, -0.08026123, -0.05033366,
#         0.14855957,  0.0328776 ,  0.00714111, -0.06003825,  0.06092326,
#        -0.04003906, -0.03932698,  0.00223796, -0.02351888, -0.05316162,
#         0.17606607, -0.09474691,  0.02571615, -0.09946188, -0.14204915,
#        -0.05249023,  0.08467611,  0.04516602,  0.19734702,  0.10894775,
#        -0.14274089, -0.18971762,  0.07958984,  0.02943929,  0.08388264,
#        -0.01490275, -0.09488932,  0.20304361,  0.08927409,  0.00459798,
#         0.10744222, -0.08664957,  0.01264445,  0.01319377, -0.1375122 ,
#         0.01774088,  0.01210531, -0.04850261,  0.03961182,  0.05554199,
#        -0.02146403, -0.11692302, -0.05706787, -0.15885417, -0.0255127 ,
#        -0.01245117, -0.00199382,  0.06858318,  0.14770508, -0.08170573,
#        -0.07725556, -0.05367025, -0.06022136,  0.01875814,  0.16365561,
#         0.04081218,  0.03006999,  0.08304341,  0.26475015,  0.02052816,
#        -0.19056702, -0.07602946, -0.21350098,  0.17378744,  0.24967447,
#        -0.1644694 , -0.01975505, -0.1653239 ,  0.00168864,  0.01861572,
#        -0.0378418 ,  0.00313314, -0.07181804,  0.11213175, -0.07061259,
#        -0.01540121,  0.07436117, -0.15551758,  0.23335776,  0.03970846,
#         0.08772786, -0.05599976, -0.1287028 ,  0.03527832, -0.04243978,
#         0.04315186, -0.07067871, -0.03193665, -0.0888265 , -0.05786133,
#         0.13720703, -0.08746338, -0.05061849,  0.05458577,  0.09233601,
#        -0.26476035, -0.10876465,  0.08484395, -0.14583333,  0.03485107,
#        -0.03491211,  0.09598796,  0.18188477, -0.06335449, -0.07572428,
#         0.04686483,  0.15307617,  0.04835001, -0.09910075,  0.01798503,
#        -0.09729004, -0.10370382, -0.02888997, -0.08542888,  0.08395895,
#         0.04250081, -0.01611328, -0.07364909, -0.02347819, -0.041097  ,
#        -0.14520264,  0.07074992, -0.11098226, -0.01731364,  0.06904094,
#         0.08701579, -0.12250773,  0.06776937,  0.02398427,  0.07170614,
#         0.02254232, -0.14082846, -0.14428711, -0.29500324, -0.00435384,
#         0.19899496,  0.00073242, -0.24023438, -0.04507065, -0.09627279,
#         0.08732096,  0.18188477, -0.20676677,  0.07174683, -0.09757487,
#        -0.01552534, -0.09261067,  0.00254313, -0.04007975, -0.06005859,
#         0.07495117, -0.0246582 ,  0.02264404,  0.05230713, -0.12719727,
#         0.17407227,  0.05574544,  0.06825764, -0.0094401 , -0.04179891,
#         0.10860189,  0.09892782, -0.04122925, -0.14542644,  0.14821371,
#        -0.00940958, -0.00293986,  0.10693359,  0.09419759,  0.09716797,
#         0.07196045, -0.10701498,  0.02356402,  0.09669495, -0.05301921,
#         0.03638712,  0.01681519,  0.19519043,  0.12306722, -0.02172852,
#         0.01172384,  0.11132812,  0.10976155, -0.2084554 ,  0.19429524,
#         0.00937907, -0.04463705,  0.29020184, -0.07590739,  0.05893962,
#        -0.04123942,  0.11735026, -0.05160522, -0.05851237,  0.00931803,
#        -0.11460368, -0.06722005, -0.03225708,  0.11019897, -0.04557292,
#         0.09729004, -0.01713053, -0.13118489, -0.07457478,  0.06842041,
#         0.10599772,  0.00801595,  0.03660075, -0.08866373, -0.12331136,
#         0.08658855,  0.05684408,  0.03173828,  0.10297648,  0.21687825,
#         0.0116272 , -0.05722888, -0.2354075 ,  0.05533854,  0.0680542 ,
#        -0.02431234, -0.03794352, -0.03580729, -0.02791341, -0.099528  ,
#         0.02812704, -0.05684408,  0.08842977, -0.21411133,  0.10742188,
#         0.03515625, -0.13989258, -0.03676351, -0.12007649, -0.01751709,
#        -0.10439046, -0.01761881, -0.05635579, -0.0953776 , -0.03859456],
#       dtype=float32)

# %%
att_mat = sio.loadmat('att_splits.mat')

# %%
all_cls = att_mat['allclasses_names']

all_cls
# Out:
# array([[array(['002.Laysan_Albatross'], dtype='<U20')],
#        [array(['003.Sooty_Albatross'], dtype='<U19')],
#        [array(['005.Crested_Auklet'], dtype='<U18')],
#        [array(['007.Parakeet_Auklet'], dtype='<U19')],
#        [array(['010.Red_winged_Blackbird'], dtype='<U24')],
#        [array(['011.Rusty_Blackbird'], dtype='<U19')],
#        [array(['012.Yellow_headed_Blackbird'], dtype='<U27')],
#        [array(['013.Bobolink'], dtype='<U12')],
#        [array(['015.Lazuli_Bunting'], dtype='<U18')],
#        [array(['016.Painted_Bunting'], dtype='<U19')],
#        [array(['017.Cardinal'], dtype='<U12')],
#        [array(['018.Spotted_Catbird'], dtype='<U19')],
#        [array(['019.Gray_Catbird'], dtype='<U16')],
#        [array(['020.Yellow_breasted_Chat'], dtype='<U24')],
#        [array(['021.Eastern_Towhee'], dtype='<U18')],
#        [array(['022.Chuck_will_Widow'], dtype='<U20')],
#        [array(['024.Red_faced_Cormorant'], dtype='<U23')],
#        [array(['025.Pelagic_Cormorant'], dtype='<U21')],
#        [array(['026.Bronzed_Cowbird'], dtype='<U19')],
#        [array(['027.Shiny_Cowbird'], dtype='<U17')],
#        [array(['028.Brown_Creeper'], dtype='<U17')],
#        [array(['030.Fish_Crow'], dtype='<U13')],
#        [array(['032.Mangrove_Cuckoo'], dtype='<U19')],
#        [array(['039.Least_Flycatcher'], dtype='<U20')],
#        [array(['040.Olive_sided_Flycatcher'], dtype='<U26')],
#        [array(['041.Scissor_tailed_Flycatcher'], dtype='<U29')],
#        [array(['042.Vermilion_Flycatcher'], dtype='<U24')],
#        [array(['044.Frigatebird'], dtype='<U15')],
#        [array(['045.Northern_Fulmar'], dtype='<U19')],
#        [array(['046.Gadwall'], dtype='<U11')],
#        [array(['047.American_Goldfinch'], dtype='<U22')],
#        [array(['048.European_Goldfinch'], dtype='<U22')],
#        [array(['050.Eared_Grebe'], dtype='<U15')],
#        [array(['052.Pied_billed_Grebe'], dtype='<U21')],
#        [array(['054.Blue_Grosbeak'], dtype='<U17')],
#        [array(['055.Evening_Grosbeak'], dtype='<U20')],
#        [array(['056.Pine_Grosbeak'], dtype='<U17')],
#        [array(['057.Rose_breasted_Grosbeak'], dtype='<U26')],
#        [array(['058.Pigeon_Guillemot'], dtype='<U20')],
#        [array(['059.California_Gull'], dtype='<U19')],
#        [array(['060.Glaucous_winged_Gull'], dtype='<U24')],
#        [array(['061.Heermann_Gull'], dtype='<U17')],
#        [array(['062.Herring_Gull'], dtype='<U16')],
#        [array(['063.Ivory_Gull'], dtype='<U14')],
#        [array(['064.Ring_billed_Gull'], dtype='<U20')],
#        [array(['065.Slaty_backed_Gull'], dtype='<U21')],
#        [array(['067.Anna_Hummingbird'], dtype='<U20')],
#        [array(['068.Ruby_throated_Hummingbird'], dtype='<U29')],
#        [array(['069.Rufous_Hummingbird'], dtype='<U22')],
#        [array(['070.Green_Violetear'], dtype='<U19')],
#        [array(['071.Long_tailed_Jaeger'], dtype='<U22')],
#        [array(['073.Blue_Jay'], dtype='<U12')],
#        [array(['074.Florida_Jay'], dtype='<U15')],
#        [array(['075.Green_Jay'], dtype='<U13')],
#        [array(['076.Dark_eyed_Junco'], dtype='<U19')],
#        [array(['077.Tropical_Kingbird'], dtype='<U21')],
#        [array(['078.Gray_Kingbird'], dtype='<U17')],
#        [array(['080.Green_Kingfisher'], dtype='<U20')],
#        [array(['081.Pied_Kingfisher'], dtype='<U19')],
#        [array(['082.Ringed_Kingfisher'], dtype='<U21')],
#        [array(['085.Horned_Lark'], dtype='<U15')],
#        [array(['087.Mallard'], dtype='<U11')],
#        [array(['088.Western_Meadowlark'], dtype='<U22')],
#        [array(['089.Hooded_Merganser'], dtype='<U20')],
#        [array(['090.Red_breasted_Merganser'], dtype='<U26')],
#        [array(['092.Nighthawk'], dtype='<U13')],
#        [array(['093.Clark_Nutcracker'], dtype='<U20')],
#        [array(['094.White_breasted_Nuthatch'], dtype='<U27')],
#        [array(['097.Orchard_Oriole'], dtype='<U18')],
#        [array(['099.Ovenbird'], dtype='<U12')],
#        [array(['100.Brown_Pelican'], dtype='<U17')],
#        [array(['104.American_Pipit'], dtype='<U18')],
#        [array(['105.Whip_poor_Will'], dtype='<U18')],
#        [array(['106.Horned_Puffin'], dtype='<U17')],
#        [array(['107.Common_Raven'], dtype='<U16')],
#        [array(['108.White_necked_Raven'], dtype='<U22')],
#        [array(['109.American_Redstart'], dtype='<U21')],
#        [array(['110.Geococcyx'], dtype='<U13')],
#        [array(['111.Loggerhead_Shrike'], dtype='<U21')],
#        [array(['113.Baird_Sparrow'], dtype='<U17')],
#        [array(['115.Brewer_Sparrow'], dtype='<U18')],
#        [array(['116.Chipping_Sparrow'], dtype='<U20')],
#        [array(['117.Clay_colored_Sparrow'], dtype='<U24')],
#        [array(['118.House_Sparrow'], dtype='<U17')],
#        [array(['120.Fox_Sparrow'], dtype='<U15')],
#        [array(['122.Harris_Sparrow'], dtype='<U18')],
#        [array(['123.Henslow_Sparrow'], dtype='<U19')],
#        [array(['124.Le_Conte_Sparrow'], dtype='<U20')],
#        [array(['125.Lincoln_Sparrow'], dtype='<U19')],
#        [array(['126.Nelson_Sharp_tailed_Sparrow'], dtype='<U31')],
#        [array(['127.Savannah_Sparrow'], dtype='<U20')],
#        [array(['128.Seaside_Sparrow'], dtype='<U19')],
#        [array(['129.Song_Sparrow'], dtype='<U16')],
#        [array(['131.Vesper_Sparrow'], dtype='<U18')],
#        [array(['132.White_crowned_Sparrow'], dtype='<U25')],
#        [array(['133.White_throated_Sparrow'], dtype='<U26')],
#        [array(['134.Cape_Glossy_Starling'], dtype='<U24')],
#        [array(['136.Barn_Swallow'], dtype='<U16')],
#        [array(['137.Cliff_Swallow'], dtype='<U17')],
#        [array(['139.Scarlet_Tanager'], dtype='<U19')],
#        [array(['140.Summer_Tanager'], dtype='<U18')],
#        [array(['141.Artic_Tern'], dtype='<U14')],
#        [array(['142.Black_Tern'], dtype='<U14')],
#        [array(['143.Caspian_Tern'], dtype='<U16')],
#        [array(['144.Common_Tern'], dtype='<U15')],
#        [array(['145.Elegant_Tern'], dtype='<U16')],
#        [array(['146.Forsters_Tern'], dtype='<U17')],
#        [array(['148.Green_tailed_Towhee'], dtype='<U23')],
#        [array(['149.Brown_Thrasher'], dtype='<U18')],
#        [array(['150.Sage_Thrasher'], dtype='<U17')],
#        [array(['151.Black_capped_Vireo'], dtype='<U22')],
#        [array(['152.Blue_headed_Vireo'], dtype='<U21')],
#        [array(['153.Philadelphia_Vireo'], dtype='<U22')],
#        [array(['154.Red_eyed_Vireo'], dtype='<U18')],
#        [array(['155.Warbling_Vireo'], dtype='<U18')],
#        [array(['157.Yellow_throated_Vireo'], dtype='<U25')],
#        [array(['158.Bay_breasted_Warbler'], dtype='<U24')],
#        [array(['159.Black_and_white_Warbler'], dtype='<U27')],
#        [array(['160.Black_throated_Blue_Warbler'], dtype='<U31')],
#        [array(['161.Blue_winged_Warbler'], dtype='<U23')],
#        [array(['162.Canada_Warbler'], dtype='<U18')],
#        [array(['164.Cerulean_Warbler'], dtype='<U20')],
#        [array(['167.Hooded_Warbler'], dtype='<U18')],
#        [array(['168.Kentucky_Warbler'], dtype='<U20')],
#        [array(['169.Magnolia_Warbler'], dtype='<U20')],
#        [array(['170.Mourning_Warbler'], dtype='<U20')],
#        [array(['171.Myrtle_Warbler'], dtype='<U18')],
#        [array(['172.Nashville_Warbler'], dtype='<U21')],
#        [array(['173.Orange_crowned_Warbler'], dtype='<U26')],
#        [array(['174.Palm_Warbler'], dtype='<U16')],
#        [array(['175.Pine_Warbler'], dtype='<U16')],
#        [array(['176.Prairie_Warbler'], dtype='<U19')],
#        [array(['177.Prothonotary_Warbler'], dtype='<U24')],
#        [array(['178.Swainson_Warbler'], dtype='<U20')],
#        [array(['179.Tennessee_Warbler'], dtype='<U21')],
#        [array(['181.Worm_eating_Warbler'], dtype='<U23')],
#        [array(['182.Yellow_Warbler'], dtype='<U18')],
#        [array(['184.Louisiana_Waterthrush'], dtype='<U25')],
#        [array(['188.Pileated_Woodpecker'], dtype='<U23')],
#        [array(['189.Red_bellied_Woodpecker'], dtype='<U26')],
#        [array(['190.Red_cockaded_Woodpecker'], dtype='<U27')],
#        [array(['191.Red_headed_Woodpecker'], dtype='<U25')],
#        [array(['192.Downy_Woodpecker'], dtype='<U20')],
#        [array(['193.Bewick_Wren'], dtype='<U15')],
#        [array(['194.Cactus_Wren'], dtype='<U15')],
#        [array(['195.Carolina_Wren'], dtype='<U17')],
#        [array(['196.House_Wren'], dtype='<U14')],
#        [array(['198.Rock_Wren'], dtype='<U13')],
#        [array(['199.Winter_Wren'], dtype='<U15')],
#        [array(['200.Common_Yellowthroat'], dtype='<U23')],
#        [array(['001.Black_footed_Albatross'], dtype='<U26')],
#        [array(['004.Groove_billed_Ani'], dtype='<U21')],
#        [array(['006.Least_Auklet'], dtype='<U16')],
#        [array(['008.Rhinoceros_Auklet'], dtype='<U21')],
#        [array(['009.Brewer_Blackbird'], dtype='<U20')],
#        [array(['014.Indigo_Bunting'], dtype='<U18')],
#        [array(['023.Brandt_Cormorant'], dtype='<U20')],
#        [array(['029.American_Crow'], dtype='<U17')],
#        [array(['031.Black_billed_Cuckoo'], dtype='<U23')],
#        [array(['033.Yellow_billed_Cuckoo'], dtype='<U24')],
#        [array(['034.Gray_crowned_Rosy_Finch'], dtype='<U27')],
#        [array(['035.Purple_Finch'], dtype='<U16')],
#        [array(['036.Northern_Flicker'], dtype='<U20')],
#        [array(['037.Acadian_Flycatcher'], dtype='<U22')],
#        [array(['038.Great_Crested_Flycatcher'], dtype='<U28')],
#        [array(['043.Yellow_bellied_Flycatcher'], dtype='<U29')],
#        [array(['049.Boat_tailed_Grackle'], dtype='<U23')],
#        [array(['051.Horned_Grebe'], dtype='<U16')],
#        [array(['053.Western_Grebe'], dtype='<U17')],
#        [array(['066.Western_Gull'], dtype='<U16')],
#        [array(['072.Pomarine_Jaeger'], dtype='<U19')],
#        [array(['079.Belted_Kingfisher'], dtype='<U21')],
#        [array(['083.White_breasted_Kingfisher'], dtype='<U29')],
#        [array(['084.Red_legged_Kittiwake'], dtype='<U24')],
#        [array(['086.Pacific_Loon'], dtype='<U16')],
#        [array(['091.Mockingbird'], dtype='<U15')],
#        [array(['095.Baltimore_Oriole'], dtype='<U20')],
#        [array(['096.Hooded_Oriole'], dtype='<U17')],
#        [array(['098.Scott_Oriole'], dtype='<U16')],
#        [array(['101.White_Pelican'], dtype='<U17')],
#        [array(['102.Western_Wood_Pewee'], dtype='<U22')],
#        [array(['103.Sayornis'], dtype='<U12')],
#        [array(['112.Great_Grey_Shrike'], dtype='<U21')],
#        [array(['114.Black_throated_Sparrow'], dtype='<U26')],
#        [array(['119.Field_Sparrow'], dtype='<U17')],
#        [array(['121.Grasshopper_Sparrow'], dtype='<U23')],
#        [array(['130.Tree_Sparrow'], dtype='<U16')],
#        [array(['135.Bank_Swallow'], dtype='<U16')],
#        [array(['138.Tree_Swallow'], dtype='<U16')],
#        [array(['147.Least_Tern'], dtype='<U14')],
#        [array(['156.White_eyed_Vireo'], dtype='<U20')],
#        [array(['163.Cape_May_Warbler'], dtype='<U20')],
#        [array(['165.Chestnut_sided_Warbler'], dtype='<U26')],
#        [array(['166.Golden_winged_Warbler'], dtype='<U25')],
#        [array(['180.Wilson_Warbler'], dtype='<U18')],
#        [array(['183.Northern_Waterthrush'], dtype='<U24')],
#        [array(['185.Bohemian_Waxwing'], dtype='<U20')],
#        [array(['186.Cedar_Waxwing'], dtype='<U17')],
#        [array(['187.American_Three_toed_Woodpecker'], dtype='<U34')],
#        [array(['197.Marsh_Wren'], dtype='<U14')]], dtype=object)

# %%
all_cls_org = [x[0][0] for x in all_cls]

all_cls_org
# Out:
# ['002.Laysan_Albatross',
#  '003.Sooty_Albatross',
#  '005.Crested_Auklet',
#  '007.Parakeet_Auklet',
#  '010.Red_winged_Blackbird',
#  '011.Rusty_Blackbird',
#  '012.Yellow_headed_Blackbird',
#  '013.Bobolink',
#  '015.Lazuli_Bunting',
#  '016.Painted_Bunting',
#  '017.Cardinal',
#  '018.Spotted_Catbird',
#  '019.Gray_Catbird',
#  '020.Yellow_breasted_Chat',
#  '021.Eastern_Towhee',
#  '022.Chuck_will_Widow',
#  '024.Red_faced_Cormorant',
#  '025.Pelagic_Cormorant',
#  '026.Bronzed_Cowbird',
#  '027.Shiny_Cowbird',
#  '028.Brown_Creeper',
#  '030.Fish_Crow',
#  '032.Mangrove_Cuckoo',
#  '039.Least_Flycatcher',
#  '040.Olive_sided_Flycatcher',
#  '041.Scissor_tailed_Flycatcher',
#  '042.Vermilion_Flycatcher',
#  '044.Frigatebird',
#  '045.Northern_Fulmar',
#  '046.Gadwall',
#  '047.American_Goldfinch',
#  '048.European_Goldfinch',
#  '050.Eared_Grebe',
#  '052.Pied_billed_Grebe',
#  '054.Blue_Grosbeak',
#  '055.Evening_Grosbeak',
#  '056.Pine_Grosbeak',
#  '057.Rose_breasted_Grosbeak',
#  '058.Pigeon_Guillemot',
#  '059.California_Gull',
#  '060.Glaucous_winged_Gull',
#  '061.Heermann_Gull',
#  '062.Herring_Gull',
#  '063.Ivory_Gull',
#  '064.Ring_billed_Gull',
#  '065.Slaty_backed_Gull',
#  '067.Anna_Hummingbird',
#  '068.Ruby_throated_Hummingbird',
#  '069.Rufous_Hummingbird',
#  '070.Green_Violetear',
#  '071.Long_tailed_Jaeger',
#  '073.Blue_Jay',
#  '074.Florida_Jay',
#  '075.Green_Jay',
#  '076.Dark_eyed_Junco',
#  '077.Tropical_Kingbird',
#  '078.Gray_Kingbird',
#  '080.Green_Kingfisher',
#  '081.Pied_Kingfisher',
#  '082.Ringed_Kingfisher',
#  '085.Horned_Lark',
#  '087.Mallard',
#  '088.Western_Meadowlark',
#  '089.Hooded_Merganser',
#  '090.Red_breasted_Merganser',
#  '092.Nighthawk',
#  '093.Clark_Nutcracker',
#  '094.White_breasted_Nuthatch',
#  '097.Orchard_Oriole',
#  '099.Ovenbird',
#  '100.Brown_Pelican',
#  '104.American_Pipit',
#  '105.Whip_poor_Will',
#  '106.Horned_Puffin',
#  '107.Common_Raven',
#  '108.White_necked_Raven',
#  '109.American_Redstart',
#  '110.Geococcyx',
#  '111.Loggerhead_Shrike',
#  '113.Baird_Sparrow',
#  '115.Brewer_Sparrow',
#  '116.Chipping_Sparrow',
#  '117.Clay_colored_Sparrow',
#  '118.House_Sparrow',
#  '120.Fox_Sparrow',
#  '122.Harris_Sparrow',
#  '123.Henslow_Sparrow',
#  '124.Le_Conte_Sparrow',
#  '125.Lincoln_Sparrow',
#  '126.Nelson_Sharp_tailed_Sparrow',
#  '127.Savannah_Sparrow',
#  '128.Seaside_Sparrow',
#  '129.Song_Sparrow',
#  '131.Vesper_Sparrow',
#  '132.White_crowned_Sparrow',
#  '133.White_throated_Sparrow',
#  '134.Cape_Glossy_Starling',
#  '136.Barn_Swallow',
#  '137.Cliff_Swallow',
#  '139.Scarlet_Tanager',
#  '140.Summer_Tanager',
#  '141.Artic_Tern',
#  '142.Black_Tern',
#  '143.Caspian_Tern',
#  '144.Common_Tern',
#  '145.Elegant_Tern',
#  '146.Forsters_Tern',
#  '148.Green_tailed_Towhee',
#  '149.Brown_Thrasher',
#  '150.Sage_Thrasher',
#  '151.Black_capped_Vireo',
#  '152.Blue_headed_Vireo',
#  '153.Philadelphia_Vireo',
#  '154.Red_eyed_Vireo',
#  '155.Warbling_Vireo',
#  '157.Yellow_throated_Vireo',
#  '158.Bay_breasted_Warbler',
#  '159.Black_and_white_Warbler',
#  '160.Black_throated_Blue_Warbler',
#  '161.Blue_winged_Warbler',
#  '162.Canada_Warbler',
#  '164.Cerulean_Warbler',
#  '167.Hooded_Warbler',
#  '168.Kentucky_Warbler',
#  '169.Magnolia_Warbler',
#  '170.Mourning_Warbler',
#  '171.Myrtle_Warbler',
#  '172.Nashville_Warbler',
#  '173.Orange_crowned_Warbler',
#  '174.Palm_Warbler',
#  '175.Pine_Warbler',
#  '176.Prairie_Warbler',
#  '177.Prothonotary_Warbler',
#  '178.Swainson_Warbler',
#  '179.Tennessee_Warbler',
#  '181.Worm_eating_Warbler',
#  '182.Yellow_Warbler',
#  '184.Louisiana_Waterthrush',
#  '188.Pileated_Woodpecker',
#  '189.Red_bellied_Woodpecker',
#  '190.Red_cockaded_Woodpecker',
#  '191.Red_headed_Woodpecker',
#  '192.Downy_Woodpecker',
#  '193.Bewick_Wren',
#  '194.Cactus_Wren',
#  '195.Carolina_Wren',
#  '196.House_Wren',
#  '198.Rock_Wren',
#  '199.Winter_Wren',
#  '200.Common_Yellowthroat',
#  '001.Black_footed_Albatross',
#  '004.Groove_billed_Ani',
#  '006.Least_Auklet',
#  '008.Rhinoceros_Auklet',
#  '009.Brewer_Blackbird',
#  '014.Indigo_Bunting',
#  '023.Brandt_Cormorant',
#  '029.American_Crow',
#  '031.Black_billed_Cuckoo',
#  '033.Yellow_billed_Cuckoo',
#  '034.Gray_crowned_Rosy_Finch',
#  '035.Purple_Finch',
#  '036.Northern_Flicker',
#  '037.Acadian_Flycatcher',
#  '038.Great_Crested_Flycatcher',
#  '043.Yellow_bellied_Flycatcher',
#  '049.Boat_tailed_Grackle',
#  '051.Horned_Grebe',
#  '053.Western_Grebe',
#  '066.Western_Gull',
#  '072.Pomarine_Jaeger',
#  '079.Belted_Kingfisher',
#  '083.White_breasted_Kingfisher',
#  '084.Red_legged_Kittiwake',
#  '086.Pacific_Loon',
#  '091.Mockingbird',
#  '095.Baltimore_Oriole',
#  '096.Hooded_Oriole',
#  '098.Scott_Oriole',
#  '101.White_Pelican',
#  '102.Western_Wood_Pewee',
#  '103.Sayornis',
#  '112.Great_Grey_Shrike',
#  '114.Black_throated_Sparrow',
#  '119.Field_Sparrow',
#  '121.Grasshopper_Sparrow',
#  '130.Tree_Sparrow',
#  '135.Bank_Swallow',
#  '138.Tree_Swallow',
#  '147.Least_Tern',
#  '156.White_eyed_Vireo',
#  '163.Cape_May_Warbler',
#  '165.Chestnut_sided_Warbler',
#  '166.Golden_winged_Warbler',
#  '180.Wilson_Warbler',
#  '183.Northern_Waterthrush',
#  '185.Bohemian_Waxwing',
#  '186.Cedar_Waxwing',
#  '187.American_Three_toed_Woodpecker',
#  '197.Marsh_Wren']

# %%
for i, c in enumerate(all_cls_org):
    all_cls_org[i] = c.split('.')[1]

all_cls_org
# Out:
# ['Laysan_Albatross',
#  'Sooty_Albatross',
#  'Crested_Auklet',
#  'Parakeet_Auklet',
#  'Red_winged_Blackbird',
#  'Rusty_Blackbird',
#  'Yellow_headed_Blackbird',
#  'Bobolink',
#  'Lazuli_Bunting',
#  'Painted_Bunting',
#  'Cardinal',
#  'Spotted_Catbird',
#  'Gray_Catbird',
#  'Yellow_breasted_Chat',
#  'Eastern_Towhee',
#  'Chuck_will_Widow',
#  'Red_faced_Cormorant',
#  'Pelagic_Cormorant',
#  'Bronzed_Cowbird',
#  'Shiny_Cowbird',
#  'Brown_Creeper',
#  'Fish_Crow',
#  'Mangrove_Cuckoo',
#  'Least_Flycatcher',
#  'Olive_sided_Flycatcher',
#  'Scissor_tailed_Flycatcher',
#  'Vermilion_Flycatcher',
#  'Frigatebird',
#  'Northern_Fulmar',
#  'Gadwall',
#  'American_Goldfinch',
#  'European_Goldfinch',
#  'Eared_Grebe',
#  'Pied_billed_Grebe',
#  'Blue_Grosbeak',
#  'Evening_Grosbeak',
#  'Pine_Grosbeak',
#  'Rose_breasted_Grosbeak',
#  'Pigeon_Guillemot',
#  'California_Gull',
#  'Glaucous_winged_Gull',
#  'Heermann_Gull',
#  'Herring_Gull',
#  'Ivory_Gull',
#  'Ring_billed_Gull',
#  'Slaty_backed_Gull',
#  'Anna_Hummingbird',
#  'Ruby_throated_Hummingbird',
#  'Rufous_Hummingbird',
#  'Green_Violetear',
#  'Long_tailed_Jaeger',
#  'Blue_Jay',
#  'Florida_Jay',
#  'Green_Jay',
#  'Dark_eyed_Junco',
#  'Tropical_Kingbird',
#  'Gray_Kingbird',
#  'Green_Kingfisher',
#  'Pied_Kingfisher',
#  'Ringed_Kingfisher',
#  'Horned_Lark',
#  'Mallard',
#  'Western_Meadowlark',
#  'Hooded_Merganser',
#  'Red_breasted_Merganser',
#  'Nighthawk',
#  'Clark_Nutcracker',
#  'White_breasted_Nuthatch',
#  'Orchard_Oriole',
#  'Ovenbird',
#  'Brown_Pelican',
#  'American_Pipit',
#  'Whip_poor_Will',
#  'Horned_Puffin',
#  'Common_Raven',
#  'White_necked_Raven',
#  'American_Redstart',
#  'Geococcyx',
#  'Loggerhead_Shrike',
#  'Baird_Sparrow',
#  'Brewer_Sparrow',
#  'Chipping_Sparrow',
#  'Clay_colored_Sparrow',
#  'House_Sparrow',
#  'Fox_Sparrow',
#  'Harris_Sparrow',
#  'Henslow_Sparrow',
#  'Le_Conte_Sparrow',
#  'Lincoln_Sparrow',
#  'Nelson_Sharp_tailed_Sparrow',
#  'Savannah_Sparrow',
#  'Seaside_Sparrow',
#  'Song_Sparrow',
#  'Vesper_Sparrow',
#  'White_crowned_Sparrow',
#  'White_throated_Sparrow',
#  'Cape_Glossy_Starling',
#  'Barn_Swallow',
#  'Cliff_Swallow',
#  'Scarlet_Tanager',
#  'Summer_Tanager',
#  'Artic_Tern',
#  'Black_Tern',
#  'Caspian_Tern',
#  'Common_Tern',
#  'Elegant_Tern',
#  'Forsters_Tern',
#  'Green_tailed_Towhee',
#  'Brown_Thrasher',
#  'Sage_Thrasher',
#  'Black_capped_Vireo',
#  'Blue_headed_Vireo',
#  'Philadelphia_Vireo',
#  'Red_eyed_Vireo',
#  'Warbling_Vireo',
#  'Yellow_throated_Vireo',
#  'Bay_breasted_Warbler',
#  'Black_and_white_Warbler',
#  'Black_throated_Blue_Warbler',
#  'Blue_winged_Warbler',
#  'Canada_Warbler',
#  'Cerulean_Warbler',
#  'Hooded_Warbler',
#  'Kentucky_Warbler',
#  'Magnolia_Warbler',
#  'Mourning_Warbler',
#  'Myrtle_Warbler',
#  'Nashville_Warbler',
#  'Orange_crowned_Warbler',
#  'Palm_Warbler',
#  'Pine_Warbler',
#  'Prairie_Warbler',
#  'Prothonotary_Warbler',
#  'Swainson_Warbler',
#  'Tennessee_Warbler',
#  'Worm_eating_Warbler',
#  'Yellow_Warbler',
#  'Louisiana_Waterthrush',
#  'Pileated_Woodpecker',
#  'Red_bellied_Woodpecker',
#  'Red_cockaded_Woodpecker',
#  'Red_headed_Woodpecker',
#  'Downy_Woodpecker',
#  'Bewick_Wren',
#  'Cactus_Wren',
#  'Carolina_Wren',
#  'House_Wren',
#  'Rock_Wren',
#  'Winter_Wren',
#  'Common_Yellowthroat',
#  'Black_footed_Albatross',
#  'Groove_billed_Ani',
#  'Least_Auklet',
#  'Rhinoceros_Auklet',
#  'Brewer_Blackbird',
#  'Indigo_Bunting',
#  'Brandt_Cormorant',
#  'American_Crow',
#  'Black_billed_Cuckoo',
#  'Yellow_billed_Cuckoo',
#  'Gray_crowned_Rosy_Finch',
#  'Purple_Finch',
#  'Northern_Flicker',
#  'Acadian_Flycatcher',
#  'Great_Crested_Flycatcher',
#  'Yellow_bellied_Flycatcher',
#  'Boat_tailed_Grackle',
#  'Horned_Grebe',
#  'Western_Grebe',
#  'Western_Gull',
#  'Pomarine_Jaeger',
#  'Belted_Kingfisher',
#  'White_breasted_Kingfisher',
#  'Red_legged_Kittiwake',
#  'Pacific_Loon',
#  'Mockingbird',
#  'Baltimore_Oriole',
#  'Hooded_Oriole',
#  'Scott_Oriole',
#  'White_Pelican',
#  'Western_Wood_Pewee',
#  'Sayornis',
#  'Great_Grey_Shrike',
#  'Black_throated_Sparrow',
#  'Field_Sparrow',
#  'Grasshopper_Sparrow',
#  'Tree_Sparrow',
#  'Bank_Swallow',
#  'Tree_Swallow',
#  'Least_Tern',
#  'White_eyed_Vireo',
#  'Cape_May_Warbler',
#  'Chestnut_sided_Warbler',
#  'Golden_winged_Warbler',
#  'Wilson_Warbler',
#  'Northern_Waterthrush',
#  'Bohemian_Waxwing',
#  'Cedar_Waxwing',
#  'American_Three_toed_Woodpecker',
#  'Marsh_Wren']

# %%
for i, c in enumerate(all_cls_org):
    all_cls_org[i] = c.replace('_', ' ')

all_cls_org
# Out:
# ['Laysan Albatross',
#  'Sooty Albatross',
#  'Crested Auklet',
#  'Parakeet Auklet',
#  'Red winged Blackbird',
#  'Rusty Blackbird',
#  'Yellow headed Blackbird',
#  'Bobolink',
#  'Lazuli Bunting',
#  'Painted Bunting',
#  'Cardinal',
#  'Spotted Catbird',
#  'Gray Catbird',
#  'Yellow breasted Chat',
#  'Eastern Towhee',
#  'Chuck will Widow',
#  'Red faced Cormorant',
#  'Pelagic Cormorant',
#  'Bronzed Cowbird',
#  'Shiny Cowbird',
#  'Brown Creeper',
#  'Fish Crow',
#  'Mangrove Cuckoo',
#  'Least Flycatcher',
#  'Olive sided Flycatcher',
#  'Scissor tailed Flycatcher',
#  'Vermilion Flycatcher',
#  'Frigatebird',
#  'Northern Fulmar',
#  'Gadwall',
#  'American Goldfinch',
#  'European Goldfinch',
#  'Eared Grebe',
#  'Pied billed Grebe',
#  'Blue Grosbeak',
#  'Evening Grosbeak',
#  'Pine Grosbeak',
#  'Rose breasted Grosbeak',
#  'Pigeon Guillemot',
#  'California Gull',
#  'Glaucous winged Gull',
#  'Heermann Gull',
#  'Herring Gull',
#  'Ivory Gull',
#  'Ring billed Gull',
#  'Slaty backed Gull',
#  'Anna Hummingbird',
#  'Ruby throated Hummingbird',
#  'Rufous Hummingbird',
#  'Green Violetear',
#  'Long tailed Jaeger',
#  'Blue Jay',
#  'Florida Jay',
#  'Green Jay',
#  'Dark eyed Junco',
#  'Tropical Kingbird',
#  'Gray Kingbird',
#  'Green Kingfisher',
#  'Pied Kingfisher',
#  'Ringed Kingfisher',
#  'Horned Lark',
#  'Mallard',
#  'Western Meadowlark',
#  'Hooded Merganser',
#  'Red breasted Merganser',
#  'Nighthawk',
#  'Clark Nutcracker',
#  'White breasted Nuthatch',
#  'Orchard Oriole',
#  'Ovenbird',
#  'Brown Pelican',
#  'American Pipit',
#  'Whip poor Will',
#  'Horned Puffin',
#  'Common Raven',
#  'White necked Raven',
#  'American Redstart',
#  'Geococcyx',
#  'Loggerhead Shrike',
#  'Baird Sparrow',
#  'Brewer Sparrow',
#  'Chipping Sparrow',
#  'Clay colored Sparrow',
#  'House Sparrow',
#  'Fox Sparrow',
#  'Harris Sparrow',
#  'Henslow Sparrow',
#  'Le Conte Sparrow',
#  'Lincoln Sparrow',
#  'Nelson Sharp tailed Sparrow',
#  'Savannah Sparrow',
#  'Seaside Sparrow',
#  'Song Sparrow',
#  'Vesper Sparrow',
#  'White crowned Sparrow',
#  'White throated Sparrow',
#  'Cape Glossy Starling',
#  'Barn Swallow',
#  'Cliff Swallow',
#  'Scarlet Tanager',
#  'Summer Tanager',
#  'Artic Tern',
#  'Black Tern',
#  'Caspian Tern',
#  'Common Tern',
#  'Elegant Tern',
#  'Forsters Tern',
#  'Green tailed Towhee',
#  'Brown Thrasher',
#  'Sage Thrasher',
#  'Black capped Vireo',
#  'Blue headed Vireo',
#  'Philadelphia Vireo',
#  'Red eyed Vireo',
#  'Warbling Vireo',
#  'Yellow throated Vireo',
#  'Bay breasted Warbler',
#  'Black and white Warbler',
#  'Black throated Blue Warbler',
#  'Blue winged Warbler',
#  'Canada Warbler',
#  'Cerulean Warbler',
#  'Hooded Warbler',
#  'Kentucky Warbler',
#  'Magnolia Warbler',
#  'Mourning Warbler',
#  'Myrtle Warbler',
#  'Nashville Warbler',
#  'Orange crowned Warbler',
#  'Palm Warbler',
#  'Pine Warbler',
#  'Prairie Warbler',
#  'Prothonotary Warbler',
#  'Swainson Warbler',
#  'Tennessee Warbler',
#  'Worm eating Warbler',
#  'Yellow Warbler',
#  'Louisiana Waterthrush',
#  'Pileated Woodpecker',
#  'Red bellied Woodpecker',
#  'Red cockaded Woodpecker',
#  'Red headed Woodpecker',
#  'Downy Woodpecker',
#  'Bewick Wren',
#  'Cactus Wren',
#  'Carolina Wren',
#  'House Wren',
#  'Rock Wren',
#  'Winter Wren',
#  'Common Yellowthroat',
#  'Black footed Albatross',
#  'Groove billed Ani',
#  'Least Auklet',
#  'Rhinoceros Auklet',
#  'Brewer Blackbird',
#  'Indigo Bunting',
#  'Brandt Cormorant',
#  'American Crow',
#  'Black billed Cuckoo',
#  'Yellow billed Cuckoo',
#  'Gray crowned Rosy Finch',
#  'Purple Finch',
#  'Northern Flicker',
#  'Acadian Flycatcher',
#  'Great Crested Flycatcher',
#  'Yellow bellied Flycatcher',
#  'Boat tailed Grackle',
#  'Horned Grebe',
#  'Western Grebe',
#  'Western Gull',
#  'Pomarine Jaeger',
#  'Belted Kingfisher',
#  'White breasted Kingfisher',
#  'Red legged Kittiwake',
#  'Pacific Loon',
#  'Mockingbird',
#  'Baltimore Oriole',
#  'Hooded Oriole',
#  'Scott Oriole',
#  'White Pelican',
#  'Western Wood Pewee',
#  'Sayornis',
#  'Great Grey Shrike',
#  'Black throated Sparrow',
#  'Field Sparrow',
#  'Grasshopper Sparrow',
#  'Tree Sparrow',
#  'Bank Swallow',
#  'Tree Swallow',
#  'Least Tern',
#  'White eyed Vireo',
#  'Cape May Warbler',
#  'Chestnut sided Warbler',
#  'Golden winged Warbler',
#  'Wilson Warbler',
#  'Northern Waterthrush',
#  'Bohemian Waxwing',
#  'Cedar Waxwing',
#  'American Three toed Woodpecker',
#  'Marsh Wren']

# %%
description = pd.read_excel('CUB_description.xlsx')
description = description.reset_index()
description.head()
# Out:
#    index               Bird_name
# 0      0  Black footed Albatross  \
# 1      1        Laysan Albatross
# 2      2         Sooty Albatross
# 3      3       Groove billed Ani
# 4      4          Crested Auklet
#
#                                    Short_Description
# 0  The Black-footed Albatross is a large seabird ...
# 1  The Laysan Albatross is a large seabird with a...
# 2  The Sooty Albatross is a large seabird known f...
# 3  The Groove-billed Ani bird is a medium-sized b...
# 4  The Crested Auklet is a small seabird with a d...

# %%
paragraphs = description['Short_Description'].tolist()

# %%
embedding = []

for c in all_cls_org:
    for index, row in description.iterrows():
        if row['Bird_name'] == c:
            print('matched: ' , row['Bird_name'], c)
            text = row['Short_Description']
            embedding.append(get_paragraph_embedding(text))
# Out:
# matched:  Laysan Albatross Laysan Albatross
# matched:  Sooty Albatross Sooty Albatross
# matched:  Crested Auklet Crested Auklet
# matched:  Parakeet Auklet Parakeet Auklet
# matched:  Red winged Blackbird Red winged Blackbird
# matched:  Rusty Blackbird Rusty Blackbird
# matched:  Yellow headed Blackbird Yellow headed Blackbird
# matched:  Bobolink Bobolink
# matched:  Lazuli Bunting Lazuli Bunting
# matched:  Painted Bunting Painted Bunting
# matched:  Cardinal Cardinal
# matched:  Spotted Catbird Spotted Catbird
# matched:  Gray Catbird Gray Catbird
# matched:  Yellow breasted Chat Yellow breasted Chat
# matched:  Eastern Towhee Eastern Towhee
# matched:  Chuck will Widow Chuck will Widow
# matched:  Red faced Cormorant Red faced Cormorant
# matched:  Pelagic Cormorant Pelagic Cormorant
# matched:  Bronzed Cowbird Bronzed Cowbird
# matched:  Shiny Cowbird Shiny Cowbird
# matched:  Brown Creeper Brown Creeper
# matched:  Fish Crow Fish Crow
# matched:  Mangrove Cuckoo Mangrove Cuckoo
# matched:  Least Flycatcher Least Flycatcher
# matched:  Olive sided Flycatcher Olive sided Flycatcher
# matched:  Scissor tailed Flycatcher Scissor tailed Flycatcher
# matched:  Vermilion Flycatcher Vermilion Flycatcher
# matched:  Frigatebird Frigatebird
# matched:  Northern Fulmar Northern Fulmar
# matched:  Gadwall Gadwall
# matched:  American Goldfinch American Goldfinch
# matched:  European Goldfinch European Goldfinch
# matched:  Eared Grebe Eared Grebe
# matched:  Pied billed Grebe Pied billed Grebe
# matched:  Blue Grosbeak Blue Grosbeak
# matched:  Evening Grosbeak Evening Grosbeak
# matched:  Pine Grosbeak Pine Grosbeak
# matched:  Rose breasted Grosbeak Rose breasted Grosbeak
# matched:  Pigeon Guillemot Pigeon Guillemot
# matched:  California Gull California Gull
# matched:  Glaucous winged Gull Glaucous winged Gull
# matched:  Heermann Gull Heermann Gull
# matched:  Herring Gull Herring Gull
# matched:  Ivory Gull Ivory Gull
# matched:  Ring billed Gull Ring billed Gull
# matched:  Slaty backed Gull Slaty backed Gull
# matched:  Anna Hummingbird Anna Hummingbird
# matched:  Ruby throated Hummingbird Ruby throated Hummingbird
# matched:  Rufous Hummingbird Rufous Hummingbird
# matched:  Green Violetear Green Violetear
# matched:  Long tailed Jaeger Long tailed Jaeger
# matched:  Blue Jay Blue Jay
# matched:  Florida Jay Florida Jay
# matched:  Green Jay Green Jay
# matched:  Dark eyed Junco Dark eyed Junco
# matched:  Tropical Kingbird Tropical Kingbird
# matched:  Gray Kingbird Gray Kingbird
# matched:  Green Kingfisher Green Kingfisher
# matched:  Pied Kingfisher Pied Kingfisher
# matched:  Ringed Kingfisher Ringed Kingfisher
# matched:  Horned Lark Horned Lark
# matched:  Mallard Mallard
# matched:  Western Meadowlark Western Meadowlark
# matched:  Hooded Merganser Hooded Merganser
# matched:  Red breasted Merganser Red breasted Merganser
# matched:  Nighthawk Nighthawk
# matched:  Clark Nutcracker Clark Nutcracker
# matched:  White breasted Nuthatch White breasted Nuthatch
# matched:  Orchard Oriole Orchard Oriole
# matched:  Ovenbird Ovenbird
# matched:  Brown Pelican Brown Pelican
# matched:  American Pipit American Pipit
# matched:  Whip poor Will Whip poor Will
# matched:  Horned Puffin Horned Puffin
# matched:  Common Raven Common Raven
# matched:  White necked Raven White necked Raven
# matched:  American Redstart American Redstart
# matched:  Geococcyx Geococcyx
# matched:  Loggerhead Shrike Loggerhead Shrike
# matched:  Baird Sparrow Baird Sparrow
# matched:  Brewer Sparrow Brewer Sparrow
# matched:  Chipping Sparrow Chipping Sparrow
# matched:  Clay colored Sparrow Clay colored Sparrow
# matched:  House Sparrow House Sparrow
# matched:  Fox Sparrow Fox Sparrow
# matched:  Harris Sparrow Harris Sparrow
# matched:  Henslow Sparrow Henslow Sparrow
# matched:  Le Conte Sparrow Le Conte Sparrow
# matched:  Lincoln Sparrow Lincoln Sparrow
# matched:  Nelson Sharp tailed Sparrow Nelson Sharp tailed Sparrow
# matched:  Savannah Sparrow Savannah Sparrow
# matched:  Seaside Sparrow Seaside Sparrow
# matched:  Song Sparrow Song Sparrow
# matched:  Vesper Sparrow Vesper Sparrow
# matched:  White crowned Sparrow White crowned Sparrow
# matched:  White throated Sparrow White throated Sparrow
# matched:  Cape Glossy Starling Cape Glossy Starling
# matched:  Barn Swallow Barn Swallow
# matched:  Cliff Swallow Cliff Swallow
# matched:  Scarlet Tanager Scarlet Tanager
# matched:  Summer Tanager Summer Tanager
# matched:  Artic Tern Artic Tern
# matched:  Black Tern Black Tern
# matched:  Caspian Tern Caspian Tern
# matched:  Common Tern Common Tern
# matched:  Elegant Tern Elegant Tern
# matched:  Forsters Tern Forsters Tern
# matched:  Green tailed Towhee Green tailed Towhee
# matched:  Brown Thrasher Brown Thrasher
# matched:  Sage Thrasher Sage Thrasher
# matched:  Black capped Vireo Black capped Vireo
# matched:  Blue headed Vireo Blue headed Vireo
# matched:  Philadelphia Vireo Philadelphia Vireo
# matched:  Red eyed Vireo Red eyed Vireo
# matched:  Warbling Vireo Warbling Vireo
# matched:  Yellow throated Vireo Yellow throated Vireo
# matched:  Bay breasted Warbler Bay breasted Warbler
# matched:  Black and white Warbler Black and white Warbler
# matched:  Black throated Blue Warbler Black throated Blue Warbler
# matched:  Blue winged Warbler Blue winged Warbler
# matched:  Canada Warbler Canada Warbler
# matched:  Cerulean Warbler Cerulean Warbler
# matched:  Hooded Warbler Hooded Warbler
# matched:  Kentucky Warbler Kentucky Warbler
# matched:  Magnolia Warbler Magnolia Warbler
# matched:  Mourning Warbler Mourning Warbler
# matched:  Myrtle Warbler Myrtle Warbler
# matched:  Nashville Warbler Nashville Warbler
# matched:  Orange crowned Warbler Orange crowned Warbler
# matched:  Palm Warbler Palm Warbler
# matched:  Pine Warbler Pine Warbler
# matched:  Prairie Warbler Prairie Warbler
# matched:  Prothonotary Warbler Prothonotary Warbler
# matched:  Swainson Warbler Swainson Warbler
# matched:  Tennessee Warbler Tennessee Warbler
# matched:  Worm eating Warbler Worm eating Warbler
# matched:  Yellow Warbler Yellow Warbler
# matched:  Louisiana Waterthrush Louisiana Waterthrush
# matched:  Pileated Woodpecker Pileated Woodpecker
# matched:  Red bellied Woodpecker Red bellied Woodpecker
# matched:  Red cockaded Woodpecker Red cockaded Woodpecker
# matched:  Red headed Woodpecker Red headed Woodpecker
# matched:  Downy Woodpecker Downy Woodpecker
# matched:  Bewick Wren Bewick Wren
# matched:  Cactus Wren Cactus Wren
# matched:  Carolina Wren Carolina Wren
# matched:  House Wren House Wren
# matched:  Rock Wren Rock Wren
# matched:  Winter Wren Winter Wren
# matched:  Common Yellowthroat Common Yellowthroat
# matched:  Black footed Albatross Black footed Albatross
# matched:  Groove billed Ani Groove billed Ani
# matched:  Least Auklet Least Auklet
# matched:  Rhinoceros Auklet Rhinoceros Auklet
# matched:  Brewer Blackbird Brewer Blackbird
# matched:  Indigo Bunting Indigo Bunting
# matched:  Brandt Cormorant Brandt Cormorant
# matched:  American Crow American Crow
# matched:  Black billed Cuckoo Black billed Cuckoo
# matched:  Yellow billed Cuckoo Yellow billed Cuckoo
# matched:  Gray crowned Rosy Finch Gray crowned Rosy Finch
# matched:  Purple Finch Purple Finch
# matched:  Northern Flicker Northern Flicker
# matched:  Acadian Flycatcher Acadian Flycatcher
# matched:  Great Crested Flycatcher Great Crested Flycatcher
# matched:  Yellow bellied Flycatcher Yellow bellied Flycatcher
# matched:  Boat tailed Grackle Boat tailed Grackle
# matched:  Horned Grebe Horned Grebe
# matched:  Western Grebe Western Grebe
# matched:  Western Gull Western Gull
# matched:  Pomarine Jaeger Pomarine Jaeger
# matched:  Belted Kingfisher Belted Kingfisher
# matched:  White breasted Kingfisher White breasted Kingfisher
# matched:  Red legged Kittiwake Red legged Kittiwake
# matched:  Pacific Loon Pacific Loon
# matched:  Mockingbird Mockingbird
# matched:  Baltimore Oriole Baltimore Oriole
# matched:  Hooded Oriole Hooded Oriole
# matched:  Scott Oriole Scott Oriole
# matched:  White Pelican White Pelican
# matched:  Western Wood Pewee Western Wood Pewee
# matched:  Sayornis Sayornis
# matched:  Great Grey Shrike Great Grey Shrike
# matched:  Black throated Sparrow Black throated Sparrow
# matched:  Field Sparrow Field Sparrow
# matched:  Grasshopper Sparrow Grasshopper Sparrow
# matched:  Tree Sparrow Tree Sparrow
# matched:  Bank Swallow Bank Swallow
# matched:  Tree Swallow Tree Swallow
# matched:  Least Tern Least Tern
# matched:  White eyed Vireo White eyed Vireo
# matched:  Cape May Warbler Cape May Warbler
# matched:  Chestnut sided Warbler Chestnut sided Warbler
# matched:  Golden winged Warbler Golden winged Warbler
# matched:  Wilson Warbler Wilson Warbler
# matched:  Northern Waterthrush Northern Waterthrush
# matched:  Bohemian Waxwing Bohemian Waxwing
# matched:  Cedar Waxwing Cedar Waxwing
# matched:  American Three toed Woodpecker American Three toed Woodpecker
# matched:  Marsh Wren Marsh Wren

# %%
embedding_array = np.vstack(embedding)

# %%
embedding_array.shape
# Out:
# (200, 300)

# %%
embedding_array
# Out:
# array([[ 0.01282   ,  0.12378289, -0.07555536, ..., -0.00654936,
#         -0.01321572,  0.04403346],
#        [ 0.05318933,  0.11495602, -0.03587015, ..., -0.02683852,
#          0.0127302 ,  0.03931695],
#        [ 0.03355895,  0.10614226, -0.05151076, ..., -0.01503086,
#          0.01835611,  0.01340824],
#        ...,
#        [ 0.04193296,  0.10132488, -0.08010884, ..., -0.03031019,
#          0.0430311 ,  0.04874269],
#        [ 0.01126219,  0.11278132, -0.05304326, ...,  0.00086981,
#          0.00733344,  0.03628048],
#        [ 0.00263848,  0.13838887, -0.08225323, ..., -0.03458618,
#          0.0262956 ,  0.01994618]], dtype=float32)

# %%
print("Min:", embedding_array.min(), ", Max:", embedding_array.max())
# Out:
# Min: -0.2551851 , Max: 0.23057702

# %%
embedding_array.shape
# Out:
# (200, 300)

# %%
print("Min:", embedding_array.min(), ", Max:", embedding_array.max())
# Out:
# Min: -0.2551851 , Max: 0.23057702

# %%
att_mat['att'].shape
# Out:
# (312, 200)

# %%
att_mat['att'] = embedding_array.T

# %%
att_mat['att'].shape
# Out:
# (300, 200)

# %%
sio.savemat('w2v_description_cub.mat', att_mat)
